# %% [markdown]
# Les 1: Tokenizer (Byte pair encoder)

# %%
import sys
sys.path.append('..')

from tokenizer import *

# %% [markdown]
# Het omzetten van een text naar tokens:

# %%
input_file_path = "../ongebruikte_scripts/wiki_nederlands.txt"

learn_encoding(input_file_path, 5, "enc_path")
# Out:
# Encoding opgeslagen in 'enc_path'.
# 575 unieke tokens gevonden.

# %% [markdown]
# De Nederlandse text in het Wiki artikel over kanker bevat 329 unieke tokens.
# Deze tokens kunnen vervolgens gebruikt worden om een text te tokeniseren:

# %%
word_list = apply_encoding(input_file_path, "enc_path")
print(word_list)
# Out:
# Tokens opgeslagen in '../ongebruikte_scripts/wiki_nederlands.tok'.
# ...

# %% [markdown]
# De tokens waaruit deze tekst bestaat:
# Wanneer de minimale woord frequentie verder omhoog gehaald zal worden zijn meer woorden opgedeeld in stukken.

# %%
vocab = decode_tokens(input_file_path, "enc_path")
print(vocab)
# Out:
# Tekst teruggeconverteerd naar '../ongebruikte_scripts/wiki_nederlands.txt'.
# ...

# %% [markdown]
# Hier is het stuk getokeniseerde text weer gedecodeerd:

# %%
with open("../ongebruikte_scripts/wiki_nederlands.txt") as f:
    print(f.read()[:200])
# Out:
# Kanker, in medisch Latijn: neoplasma malignum: 'kwaadaardig, nieuwgevormd weefsel', is een ziekte die zich als volgt uit:
#
#
#
# er zijn cellen die zich onbeheerst vermenigvuldigen en dit blijven doen;
